# %%
from capstone_traffic_light_classification import estimator as estimator_lib
import tensorflow as tf
from functools import partial

# %%
sess=tf.InteractiveSession()
estimaor=estimator_lib.estimator_fn(params={"num_classes":4, "train_dir":"./logs"})
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_save_summary_steps': 100, '_task_type': 'worker', '_keep_checkpoint_max': 5, '_num_worker_replicas': 1, '_is_chief': True, '_service': None, '_task_id': 0, '_model_dir': './logs', '_num_ps_replicas': 0, '_tf_random_seed': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f65a4ff1978>, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_session_config': None, '_save_checkpoints_steps': None, '_master': '', '_save_checkpoints_secs': 600}

# %%
estimaor.train(partial(estimator_lib.train_input_fn, training_dir="../sdc-data/"))
# Out:
# {'num_classes': 4, 'train_dir': './logs'}
# INFO:tensorflow:Scale of 0 disables regularizer.
# INFO:tensorflow:Scale of 0 disables regularizer.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into ./logs/model.ckpt.
# INFO:tensorflow:step = 1, loss = 0.889379
# INFO:tensorflow:global_step/sec: 2.06415
# INFO:tensorflow:step = 101, loss = 0.183259 (48.455 sec)
# INFO:tensorflow:global_step/sec: 2.16145
# INFO:tensorflow:step = 201, loss = 0.0519064 (46.271 sec)
# INFO:tensorflow:global_step/sec: 2.14877
# INFO:tensorflow:step = 301, loss = 0.0805117 (46.541 sec)
# INFO:tensorflow:global_step/sec: 2.12461
# INFO:tensorflow:step = 401, loss = 0.113089 (47.067 sec)
# INFO:tensorflow:global_step/sec: 2.1709
# INFO:tensorflow:step = 501, loss = 0.0570835 (46.066 sec)
# INFO:tensorflow:global_step/sec: 2.18287
# INFO:tensorflow:step = 601, loss = 0.316509 (45.794 sec)
# INFO:tensorflow:global_step/sec: 2.13707
# ...
